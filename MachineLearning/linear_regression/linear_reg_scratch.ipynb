# %%
import numpy as np
import pandas as pd
import matplotlib_inline as plt

# %%
data = pd.read_csv('c:/Users/vamsh/ML_GENAI/MachineLearningandGenerativeAI/MachineLearning/linear_regression/house_prices.csv')
