# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\vamsh\ML_GENAI\MachineLearningandGenerativeAI\MachineLearningandGenerativeAI\MachineLearning\decision_tree_practical_imp\bike_rentals.csv")
df.head(5)
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
df.shape
# Out:
# (10886, 12)

# %%
df.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# ...

# %%
df.isnull().sum()
# Out:
# datetime      0
# season        0
# holiday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# casual        0
# registered    0
# count         0
# dtype: int64

# %%
df.drop(['datetime'], axis=1, inplace=True)

# %%
df.head(5)
# Out:
#    season  holiday  workingday  weather  temp   atemp  humidity  windspeed  \
# 0       1        0           0        1  9.84  14.395        81        0.0
# 1       1        0           0        1  9.02  13.635        80        0.0
# 2       1        0           0        1  9.02  13.635        80        0.0
# 3       1        0           0        1  9.84  14.395        75        0.0
# 4       1        0           0        1  9.84  14.395        75        0.0
#
#    casual  registered  count
# 0       3          13     16
# 1       8          32     40
# 2       5          27     32
# 3       3          10     13
# 4       0           1      1

# %%
plt.hist(df['count'])
plt.xlabel("Count of Bikes")
plt.ylabel("Freq")
plt.title("Histogram of count")
# Out:
# Text(0.5, 1.0, 'Histogram of count')

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
X
# Out:
#        season  holiday  workingday  weather   temp   atemp  humidity  \
# 0           1        0           0        1   9.84  14.395        81
# 1           1        0           0        1   9.02  13.635        80
# 2           1        0           0        1   9.02  13.635        80
# 3           1        0           0        1   9.84  14.395        75
# 4           1        0           0        1   9.84  14.395        75
# ...       ...      ...         ...      ...    ...     ...       ...
# 10881       4        0           1        1  15.58  19.695        50
# 10882       4        0           1        1  14.76  17.425        57
# 10883       4        0           1        1  13.94  15.910        61
# 10884       4        0           1        1  13.94  17.425        61
# 10885       4        0           1        1  13.12  16.665        66
#
#        windspeed  casual  registered
# 0         0.0000       3          13
# 1         0.0000       8          32
# ...

# %%
y
# Out:
# 0         16
# 1         40
# 2         32
# 3         13
# 4          1
#         ...
# 10881    336
# 10882    241
# 10883    168
# 10884    129
# 10885     88
# Name: count, Length: 10886, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.shape
# Out:
# (7620, 10)

# %%
y_train.shape
# Out:
# (7620,)

# %%
from sklearn.tree import DecisionTreeRegressor

reg = DecisionTreeRegressor(criterion="friedman_mse",
                            max_depth=8,
                            min_samples_split=10,
                            random_state=42)

# %%
reg.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='friedman_mse', max_depth=8,
#                       min_samples_split=10, random_state=42)

# %%
y_pred = reg.predict(X_test)
y_pred
# Out:
# array([128.41071429,  14.66990291, 154.26785714, ..., 259.02564103,
#        144.51612903,   1.67204301], shape=(3266,))

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_test, y_pred)
# Out:
# 93.78736235430489

# %%
np.sqrt(mean_squared_error(y_test, y_pred)
)
# Out:
# np.float64(9.684387557006632)

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(reg, X_train, y_train, cv=10)
# Out:
# array([0.99688991, 0.99677688, 0.99742379, 0.99699725, 0.99746204,
#        0.99723971, 0.99560549, 0.99741309, 0.99720964, 0.99592823])
